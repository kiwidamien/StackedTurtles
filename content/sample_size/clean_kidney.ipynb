# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pickle

plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ## Load data
#
# * Load in the data
# * Clean the column names
# * Drop spurious column

# %%
incidence=pd.read_csv('incd.csv', encoding='latin1', skiprows=8)
incidence.head()
# Out:
#                              County     FIPS  \
# 0              US (SEER+NPCR)(1,10)      0.0
# 1       Cass County, Illinois(6,10)  17017.0
# 2       Union County, Florida(6,10)  12125.0
# 3     Greene County, Illinois(6,10)  17061.0
# 4  Benton County, Mississippi(6,10)  28009.0
#
#   Met Healthy People Objective of ***?  \
# 0                                  ***
# 1                                  ***
# 2                                  ***
# 3                                  ***
# 4                                  ***
#
#   Age-Adjusted Incidence Rate() - cases per 100,000  \
# 0                                              16.4
# 1                                              41.1
# 2                                              38.7
# 3                                              37.5
# 4                                              36.6
#
#   Lower 95% Confidence Interval Upper 95% Confidence Interval  \
# 0                          16.3                          16.4
# 1                            28                          58.5
# 2                          26.6                          54.9
# 3                          24.7                          54.9
# 4                          21.2                          59.1
#
#   Average Annual Count Recent Trend  \
# 0                58599       rising
# 1                    7       rising
# 2                    7       stable
# 3                    6       stable
# 4                    4       stable
#
#   Recent 5-Year Trend () in Incidence Rates Lower 95% Confidence Interval.1  \
# 0                                       0.8                              0.6
# 1                                      35.1                             19.0
# 2                                     -16.9                            -37.4
# 3                                      28.7                            -19.6
# 4                                      23.4                             -1.4
#
#   Upper 95% Confidence Interval.1
# 0                             0.9
# 1                            53.4
# 2                            10.4
# 3                           106.1
# 4                            54.4

# %%
incidence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3162 entries, 0 to 3161
# Data columns (total 11 columns):
# County                                                3162 non-null object
#  FIPS                                                 3142 non-null float64
# Met Healthy People Objective of ***?                  3142 non-null object
# Age-Adjusted Incidence Rate() - cases per 100,000    3142 non-null object
# Lower 95% Confidence Interval                         3142 non-null object
# Upper 95% Confidence Interval                         3142 non-null object
# Average Annual Count                                  3142 non-null object
# Recent Trend                                          3142 non-null object
# Recent 5-Year Trend () in Incidence Rates            3142 non-null object
# Lower 95% Confidence Interval.1                       3142 non-null object
# Upper 95% Confidence Interval.1                       3142 non-null object
# dtypes: float64(1), object(10)
# memory usage: 271.8+ KB

# %%
incidence.columns
# Out:
# Index(['County', ' FIPS', 'Met Healthy People Objective of ***?',
#        'Age-Adjusted Incidence Rate() - cases per 100,000',
#        'Lower 95% Confidence Interval', 'Upper 95% Confidence Interval',
#        'Average Annual Count', 'Recent Trend',
#        'Recent 5-Year Trend () in Incidence Rates',
#        'Lower 95% Confidence Interval.1', 'Upper 95% Confidence Interval.1'],
#       dtype='object')

# %%
incidence.columns = ['County', 'FIPS', 'Unknown', 'Rate_per_100k', 'lower_95', 'upper_95', 'average_annual_count',
                    'trend', '5_yr_trend', 'lower_95_ci_1', 'upper_95_ci_1']

# %%
incidence.drop('Unknown', axis=1, inplace=True)

# %%
incidence.head()
# Out:
#                              County     FIPS Rate_per_100k lower_95 upper_95  \
# 0              US (SEER+NPCR)(1,10)      0.0         16.4      16.3     16.4
# 1       Cass County, Illinois(6,10)  17017.0         41.1        28     58.5
# 2       Union County, Florida(6,10)  12125.0         38.7      26.6     54.9
# 3     Greene County, Illinois(6,10)  17061.0         37.5      24.7     54.9
# 4  Benton County, Mississippi(6,10)  28009.0         36.6      21.2     59.1
#
#   average_annual_count   trend 5_yr_trend lower_95_ci_1 upper_95_ci_1
# 0                58599  rising       0.8            0.6           0.9
# 1                    7  rising      35.1           19.0          53.4
# 2                    7  stable     -16.9          -37.4          10.4
# 3                    6  stable      28.7          -19.6         106.1
# 4                    4  stable      23.4           -1.4          54.4

# %% [markdown]
# ## Do data conversions
#
# Some junk in some of the columns, causing them to be "objects". Convert to correct numeric types. We will see data isn't available for NV, so we will drop those rows.

# %%
error_mask = pd.to_numeric(incidence['Rate_per_100k'], errors='coerce').isna()
incidence[error_mask]
# Out:
#                                                  County     FIPS  \
# 25                       Osceola County, Michigan(6,10)  26133.0
# 184                 Presque Isle County, Michigan(6,10)  26141.0
# 330                    Roscommon County, Michigan(6,10)  26143.0
# 454                    Van Buren County, Michigan(6,10)  26159.0
# 630                          Bay County, Michigan(6,10)  26017.0
# 633                        Delta County, Michigan(6,10)  26041.0
# 651                      Berrien County, Michigan(6,10)  26021.0
# 695                     Chippewa County, Michigan(6,10)  26033.0
# 797                       Otsego County, Michigan(6,10)  26137.0
# 816                        Ionia County, Michigan(6,10)  26067.0
# 824                    Menominee County, Michigan(6,10)  26109.0
# 828                       Ogemaw County, Michigan(6,10)  26129.0
# 833                       Benzie County, Michigan(6,10)  26019.0
# 894                      Tuscola County, Michigan(6,10)  26157.0
# 933                      Wexford County, Michigan(6,10)  26165.0
# 943                    Cheboygan County, Michigan(6,10)  26031.0
# 953                   Shiawassee County, Michigan(6,10)  26155.0
# 955                      Genesee County, Michigan(6,10)  26049.0
# 1024                       Huron County, Michigan(6,10)  26063.0
# 1042                     Lenawee County, Michigan(6,10)  26091.0
# 1044                      Arenac County, Michigan(6,10)  26011.0
# 1125                     Gladwin County, Michigan(6,10)  26051.0
# 1140                    Manistee County, Michigan(6,10)  26101.0
# 1162                      Lapeer County, Michigan(6,10)  26087.0
# 1166                      Ingham County, Michigan(6,10)  26065.0
# 1181                    Isabella County, Michigan(6,10)  26073.0
# 1215                        Kent County, Michigan(6,10)  26081.0
# 1251                        Lake County, Michigan(6,10)  26085.0
# 1293                    Muskegon County, Michigan(6,10)  26121.0
# 1346                      Antrim County, Michigan(6,10)  26009.0
# ...                                                 ...      ...
# 3132                         Humboldt County, Nevada(6)  32013.0
# 3133                           Lander County, Nevada(6)  32015.0
# 3134                          Lincoln County, Nevada(6)  32017.0
# 3135                             Lyon County, Nevada(6)  32019.0
# 3136                          Mineral County, Nevada(6)  32021.0
# 3137                              Nye County, Nevada(6)  32023.0
# 3138                         Pershing County, Nevada(6)  32027.0
# 3139                           Storey County, Nevada(6)  32029.0
# 3140                           Washoe County, Nevada(6)  32031.0
# 3141                       White Pine County, Nevada(6)  32033.0
# 3142  Created by statecancerprofiles.cancer.gov on 1...      NaN
# 3143  Data for the United States does not include da...      NaN
# 3144  *** No Healthy People 2020 Objective for this ...      NaN
# 3145  State Cancer Registries may provide more curre...      NaN
# 3146   Incidence rates (cases per 100,000 populatio...      NaN
# 3147   Incidence data come from different sources. ...      NaN
# 3148  Healthy People 2020 Objectives [ https://www.h...      NaN
# 3149   ¶ Data not available because of state legisla...      NaN
# 3150  # Data do not include cases diagnosed in other...      NaN
# 3151  * Data has been suppressed to ensure confident...      NaN
# 3152                  ¶¶ Data not available for Nevada.      NaN
# 3153  1 Source: CDC's National Program of Cancer Reg...      NaN
# 3154  6 Source: State Cancer Registry and the CDC's ...      NaN
# 3155           7 Source: SEER November 2017 submission.      NaN
# 3156  8 Source: Incidence data provided by the SEER ...      NaN
# 3157  10 Source: Incidence data provided by the Nati...      NaN
# 3158  Please note that the data comes from different...      NaN
# 3159  Interpret Rankings provides insight into inter...      NaN
# 3160  Data not available [http://statecancerprofiles...      NaN
# 3161  Data for United States does not include Puerto...      NaN
#
#      Rate_per_100k lower_95 upper_95 average_annual_count    trend 5_yr_trend  \
# 25        30.7 #       22.3     41.4                   10   stable      -6.6
# 184       23.9 #       13.3     40.1                    5   stable     -19.0
# 330       22.1 #         16     30.5                   11   stable       7.4
# 454       20.9 #       16.8     25.8                   19   stable      -5.6
# 630       19.6 #       16.3     23.5                   27   stable      -1.6
# 633       19.6 #       14.4     26.3                   11   stable       3.8
# 651       19.5 #       16.8     22.7                   38   stable       2.2
# 695       19.3 #         14     26.1                    9   stable       8.2
# 797       18.7 #       12.5     27.3                    6   stable       4.4
# 816       18.6 #       14.3     23.8                   13   stable      -6.8
# 824       18.6 #       12.3     27.3                    6   stable     -18.3
# 828       18.5 #       11.6     28.4                    5   stable       1.1
# 833       18.5 #       11.2     29.2                    5   stable      12.4
# 894       18.2 #       13.8     23.7                   13   stable      -7.8
# 933       18.1 #       12.8       25                    8  falling     -22.3
# 943         18 #       12.3       26                    7   stable       4.3
# 953         18 #       14.2     22.6                   16   stable      -2.6
# 955         18 #       16.3     19.8                   90   stable       2.0
# 1024      17.7 #       12.1     25.1                    8   stable      10.9
# 1042      17.6 #       14.4     21.3                   23   stable      -8.3
# 1044      17.6 #       10.2     28.9                    4   stable     -19.2
# 1125      17.2 #       11.6     25.1                    7   stable      -6.1
# 1140      17.2 #       11.6     24.9                    7   stable     -14.4
# 1162      17.1 #       13.8       21                   20   stable      -3.0
# 1166        17 #       14.8     19.5                   46   stable     -11.7
# 1181        17 #       12.4     22.6                   10   stable       1.4
# 1215      16.8 #       15.4     18.3                  107   stable      -2.6
# 1251      16.7 #        9.4     29.2                    3        *          *
# 1293      16.5 #         14     19.3                   33   stable       5.6
# 1346      16.3 #       10.6     24.4                    6   stable      14.5
# ...            ...      ...      ...                  ...      ...        ...
# 3132           ¶¶        ¶¶       ¶¶                   ¶¶       ¶¶         ¶¶
# 3133           ¶¶        ¶¶       ¶¶                   ¶¶       ¶¶         ¶¶
# 3134           ¶¶        ¶¶       ¶¶                   ¶¶       ¶¶         ¶¶
# 3135           ¶¶        ¶¶       ¶¶                   ¶¶       ¶¶         ¶¶
# 3136           ¶¶        ¶¶       ¶¶                   ¶¶       ¶¶         ¶¶
# 3137           ¶¶        ¶¶       ¶¶                   ¶¶       ¶¶         ¶¶
# 3138           ¶¶        ¶¶       ¶¶                   ¶¶       ¶¶         ¶¶
# 3139           ¶¶        ¶¶       ¶¶                   ¶¶       ¶¶         ¶¶
# 3140           ¶¶        ¶¶       ¶¶                   ¶¶       ¶¶         ¶¶
# 3141           ¶¶        ¶¶       ¶¶                   ¶¶       ¶¶         ¶¶
# 3142           NaN      NaN      NaN                  NaN      NaN        NaN
# 3143           NaN      NaN      NaN                  NaN      NaN        NaN
# 3144           NaN      NaN      NaN                  NaN      NaN        NaN
# 3145           NaN      NaN      NaN                  NaN      NaN        NaN
# 3146           NaN      NaN      NaN                  NaN      NaN        NaN
# 3147           NaN      NaN      NaN                  NaN      NaN        NaN
# 3148           NaN      NaN      NaN                  NaN      NaN        NaN
# 3149           NaN      NaN      NaN                  NaN      NaN        NaN
# 3150           NaN      NaN      NaN                  NaN      NaN        NaN
# 3151           NaN      NaN      NaN                  NaN      NaN        NaN
# 3152           NaN      NaN      NaN                  NaN      NaN        NaN
# 3153           NaN      NaN      NaN                  NaN      NaN        NaN
# 3154           NaN      NaN      NaN                  NaN      NaN        NaN
# 3155           NaN      NaN      NaN                  NaN      NaN        NaN
# 3156           NaN      NaN      NaN                  NaN      NaN        NaN
# 3157           NaN      NaN      NaN                  NaN      NaN        NaN
# 3158           NaN      NaN      NaN                  NaN      NaN        NaN
# 3159           NaN      NaN      NaN                  NaN      NaN        NaN
# 3160           NaN      NaN      NaN                  NaN      NaN        NaN
# 3161           NaN      NaN      NaN                  NaN      NaN        NaN
#
#      lower_95_ci_1 upper_95_ci_1
# 25           -24.9          16.0
# 184          -66.5          96.1
# 330          -20.6          45.2
# 454          -20.8          12.4
# 630          -16.9          16.5
# 633          -15.1          27.0
# 651           -8.1          13.6
# 695          -33.0          74.5
# 797          -31.9          60.2
# 816          -24.2          14.7
# 824          -67.0         101.8
# 828          -19.0          26.2
# 833          -15.7          49.9
# 894          -28.8          19.3
# 933          -31.8         -11.4
# 943          -31.7          59.3
# 953          -20.8          19.9
# 955           -9.9          15.5
# 1024         -30.1          76.1
# 1042         -38.8          37.4
# 1044         -52.2          36.6
# 1125         -33.1          31.8
# 1140         -53.9          59.2
# 1162         -18.6          15.6
# 1166         -24.1           2.7
# 1181         -16.1          22.7
# 1215         -20.8          19.9
# 1251             *             *
# 1293          -9.0          22.6
# 1346         -44.7         137.1
# ...            ...           ...
# 3132            ¶¶            ¶¶
# 3133            ¶¶            ¶¶
# 3134            ¶¶            ¶¶
# 3135            ¶¶            ¶¶
# 3136            ¶¶            ¶¶
# 3137            ¶¶            ¶¶
# 3138            ¶¶            ¶¶
# 3139            ¶¶            ¶¶
# 3140            ¶¶            ¶¶
# 3141            ¶¶            ¶¶
# 3142           NaN           NaN
# 3143           NaN           NaN
# 3144           NaN           NaN
# 3145           NaN           NaN
# 3146           NaN           NaN
# 3147           NaN           NaN
# 3148           NaN           NaN
# 3149           NaN           NaN
# 3150           NaN           NaN
# 3151           NaN           NaN
# 3152           NaN           NaN
# 3153           NaN           NaN
# 3154           NaN           NaN
# 3155           NaN           NaN
# 3156           NaN           NaN
# 3157           NaN           NaN
# 3158           NaN           NaN
# 3159           NaN           NaN
# 3160           NaN           NaN
# 3161           NaN           NaN
#
# [1162 rows x 10 columns]

# %% [markdown]
# Ok, row 3142 onward are `NaN` because they are footer notes at the end of the file. We will use FIPS being `NaN` as a  programmatic way of detecting this, and checking we only delete the desired rows

# %%
footer_mask = incidence['FIPS'].isna()
incidence[footer_mask]
# Out:
#                                                  County  FIPS Rate_per_100k  \
# 3142  Created by statecancerprofiles.cancer.gov on 1...   NaN           NaN
# 3143  Data for the United States does not include da...   NaN           NaN
# 3144  *** No Healthy People 2020 Objective for this ...   NaN           NaN
# 3145  State Cancer Registries may provide more curre...   NaN           NaN
# 3146   Incidence rates (cases per 100,000 populatio...   NaN           NaN
# 3147   Incidence data come from different sources. ...   NaN           NaN
# 3148  Healthy People 2020 Objectives [ https://www.h...   NaN           NaN
# 3149   ¶ Data not available because of state legisla...   NaN           NaN
# 3150  # Data do not include cases diagnosed in other...   NaN           NaN
# 3151  * Data has been suppressed to ensure confident...   NaN           NaN
# 3152                  ¶¶ Data not available for Nevada.   NaN           NaN
# 3153  1 Source: CDC's National Program of Cancer Reg...   NaN           NaN
# 3154  6 Source: State Cancer Registry and the CDC's ...   NaN           NaN
# 3155           7 Source: SEER November 2017 submission.   NaN           NaN
# 3156  8 Source: Incidence data provided by the SEER ...   NaN           NaN
# 3157  10 Source: Incidence data provided by the Nati...   NaN           NaN
# 3158  Please note that the data comes from different...   NaN           NaN
# 3159  Interpret Rankings provides insight into inter...   NaN           NaN
# 3160  Data not available [http://statecancerprofiles...   NaN           NaN
# 3161  Data for United States does not include Puerto...   NaN           NaN
#
#      lower_95 upper_95 average_annual_count trend 5_yr_trend lower_95_ci_1  \
# 3142      NaN      NaN                  NaN   NaN        NaN           NaN
# 3143      NaN      NaN                  NaN   NaN        NaN           NaN
# 3144      NaN      NaN                  NaN   NaN        NaN           NaN
# 3145      NaN      NaN                  NaN   NaN        NaN           NaN
# 3146      NaN      NaN                  NaN   NaN        NaN           NaN
# 3147      NaN      NaN                  NaN   NaN        NaN           NaN
# 3148      NaN      NaN                  NaN   NaN        NaN           NaN
# 3149      NaN      NaN                  NaN   NaN        NaN           NaN
# 3150      NaN      NaN                  NaN   NaN        NaN           NaN
# 3151      NaN      NaN                  NaN   NaN        NaN           NaN
# 3152      NaN      NaN                  NaN   NaN        NaN           NaN
# 3153      NaN      NaN                  NaN   NaN        NaN           NaN
# 3154      NaN      NaN                  NaN   NaN        NaN           NaN
# 3155      NaN      NaN                  NaN   NaN        NaN           NaN
# 3156      NaN      NaN                  NaN   NaN        NaN           NaN
# 3157      NaN      NaN                  NaN   NaN        NaN           NaN
# 3158      NaN      NaN                  NaN   NaN        NaN           NaN
# 3159      NaN      NaN                  NaN   NaN        NaN           NaN
# 3160      NaN      NaN                  NaN   NaN        NaN           NaN
# 3161      NaN      NaN                  NaN   NaN        NaN           NaN
#
#      upper_95_ci_1
# 3142           NaN
# 3143           NaN
# 3144           NaN
# 3145           NaN
# 3146           NaN
# 3147           NaN
# 3148           NaN
# 3149           NaN
# 3150           NaN
# 3151           NaN
# 3152           NaN
# 3153           NaN
# 3154           NaN
# 3155           NaN
# 3156           NaN
# 3157           NaN
# 3158           NaN
# 3159           NaN
# 3160           NaN
# 3161           NaN

# %%
incidence = incidence[~footer_mask]

# %%
incidence['Rate_per_100k'] = incidence['Rate_per_100k'].str.replace('#', '')
error_mask = pd.to_numeric(incidence['Rate_per_100k'], errors='coerce').isna()
incidence[error_mask]
# Out:
#                                         County     FIPS Rate_per_100k  \
# 2065                     Adair County, Iowa(7)  19001.0            *
# 2066                 Adair County, Kentucky(7)  21001.0            *
# 2067              Adair County, Missouri(6,10)  29001.0            *
# 2068                 Adams County, Idaho(6,10)  16003.0            *
# 2069                     Adams County, Iowa(7)  19003.0            *
# 2070          Adams County, North Dakota(6,10)  38001.0            *
# 2071            Adams County, Washington(6,10)  53001.0            *
# 2072            Alamosa County, Colorado(6,10)   8003.0            *
# 2073              Albany County, Wyoming(6,10)  56001.0            *
# 2074             Alcona County, Michigan(6,10)  26001.0            *
# 2075      Aleutians East Borough, Alaska(6,10)   2013.0            *
# 2076  Aleutians West Census Area, Alaska(6,10)   2016.0            *
# 2077          Alexander County, Illinois(6,10)  17003.0            *
# 2078            Alfalfa County, Oklahoma(6,10)  40003.0            *
# 2079              Alger County, Michigan(6,10)  26003.0            *
# 2080    Alleghany County, North Carolina(6,10)  37005.0            *
# 2081    Allendale County, South Carolina(6,10)  45005.0            *
# 2082              Alpine County, California(7)   6003.0            *
# 2083           Antelope County, Nebraska(6,10)  31003.0            *
# 2084         Appomattox County, Virginia(6,10)  51011.0            *
# 2085                Archer County, Texas(6,10)  48009.0            *
# 2086          Archuleta County, Colorado(6,10)   8007.0            *
# 2087             Armstrong County, Texas(6,10)  48011.0            *
# 2088             Arthur County, Nebraska(6,10)  31005.0            *
# 2089           Atchison County, Missouri(6,10)  29005.0            *
# 2090               Atkinson County, Georgia(7)  13003.0            *
# 2091                   Audubon County, Iowa(7)  19009.0            *
# 2092         Aurora County, South Dakota(6,10)  46003.0            *
# 2093        Avery County, North Carolina(6,10)  37011.0            *
# 2094               Baca County, Colorado(6,10)   8009.0            *
# ...                                        ...      ...           ...
# 3112                 Wallace County, Kansas(6)  20199.0            ¶
# 3113               Waseca County, Minnesota(6)  27161.0            ¶
# 3114              Washington County, Kansas(6)  20201.0            ¶
# 3115           Washington County, Minnesota(6)  27163.0            ¶
# 3116             Watonwan County, Minnesota(6)  27165.0            ¶
# 3117                 Wichita County, Kansas(6)  20203.0            ¶
# 3118               Wilkin County, Minnesota(6)  27167.0            ¶
# 3119                  Wilson County, Kansas(6)  20205.0            ¶
# 3120               Winona County, Minnesota(6)  27169.0            ¶
# 3121                 Woodson County, Kansas(6)  20207.0            ¶
# 3122               Wright County, Minnesota(6)  27171.0            ¶
# 3123               Wyandotte County, Kansas(6)  20209.0            ¶
# 3124      Yellow Medicine County, Minnesota(6)  27173.0            ¶
# 3125                    Carson City, Nevada(6)  32510.0           ¶¶
# 3126               Churchill County, Nevada(6)  32001.0           ¶¶
# 3127                   Clark County, Nevada(6)  32003.0           ¶¶
# 3128                 Douglas County, Nevada(6)  32005.0           ¶¶
# 3129                    Elko County, Nevada(6)  32007.0           ¶¶
# 3130               Esmeralda County, Nevada(6)  32009.0           ¶¶
# 3131                  Eureka County, Nevada(6)  32011.0           ¶¶
# 3132                Humboldt County, Nevada(6)  32013.0           ¶¶
# 3133                  Lander County, Nevada(6)  32015.0           ¶¶
# 3134                 Lincoln County, Nevada(6)  32017.0           ¶¶
# 3135                    Lyon County, Nevada(6)  32019.0           ¶¶
# 3136                 Mineral County, Nevada(6)  32021.0           ¶¶
# 3137                     Nye County, Nevada(6)  32023.0           ¶¶
# 3138                Pershing County, Nevada(6)  32027.0           ¶¶
# 3139                  Storey County, Nevada(6)  32029.0           ¶¶
# 3140                  Washoe County, Nevada(6)  32031.0           ¶¶
# 3141              White Pine County, Nevada(6)  32033.0           ¶¶
#
#      lower_95 upper_95 average_annual_count trend 5_yr_trend lower_95_ci_1  \
# 2065        *        *           3 or fewer     *          *             *
# 2066        *        *           3 or fewer     *          *             *
# 2067        *        *           3 or fewer     *          *             *
# 2068        *        *           3 or fewer     *          *             *
# 2069        *        *           3 or fewer     *          *             *
# 2070        *        *           3 or fewer     *          *             *
# 2071        *        *           3 or fewer     *          *             *
# 2072        *        *           3 or fewer     *          *             *
# 2073        *        *           3 or fewer     *          *             *
# 2074        *        *           3 or fewer     *          *             *
# 2075        *        *           3 or fewer     *          *             *
# 2076        *        *           3 or fewer     *          *             *
# 2077        *        *           3 or fewer     *          *             *
# 2078        *        *           3 or fewer     *          *             *
# 2079        *        *           3 or fewer     *          *             *
# 2080        *        *           3 or fewer     *          *             *
# 2081        *        *           3 or fewer     *          *             *
# 2082        *        *           3 or fewer     *          *             *
# 2083        *        *           3 or fewer     *          *             *
# 2084        *        *           3 or fewer     *          *             *
# 2085        *        *           3 or fewer     *          *             *
# 2086        *        *           3 or fewer     *          *             *
# 2087        *        *           3 or fewer     *          *             *
# 2088        *        *           3 or fewer     *          *             *
# 2089        *        *           3 or fewer     *          *             *
# 2090        *        *           3 or fewer     *          *             *
# 2091        *        *           3 or fewer     *          *             *
# 2092        *        *           3 or fewer     *          *             *
# 2093        *        *           3 or fewer     *          *             *
# 2094        *        *           3 or fewer     *          *             *
# ...       ...      ...                  ...   ...        ...           ...
# 3112        ¶        ¶                    ¶     ¶          ¶             ¶
# 3113        ¶        ¶                    ¶     ¶          ¶             ¶
# 3114        ¶        ¶                    ¶     ¶          ¶             ¶
# 3115        ¶        ¶                    ¶     ¶          ¶             ¶
# 3116        ¶        ¶                    ¶     ¶          ¶             ¶
# 3117        ¶        ¶                    ¶     ¶          ¶             ¶
# 3118        ¶        ¶                    ¶     ¶          ¶             ¶
# 3119        ¶        ¶                    ¶     ¶          ¶             ¶
# 3120        ¶        ¶                    ¶     ¶          ¶             ¶
# 3121        ¶        ¶                    ¶     ¶          ¶             ¶
# 3122        ¶        ¶                    ¶     ¶          ¶             ¶
# 3123        ¶        ¶                    ¶     ¶          ¶             ¶
# 3124        ¶        ¶                    ¶     ¶          ¶             ¶
# 3125       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3126       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3127       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3128       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3129       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3130       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3131       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3132       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3133       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3134       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3135       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3136       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3137       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3138       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3139       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3140       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
# 3141       ¶¶       ¶¶                   ¶¶    ¶¶         ¶¶            ¶¶
#
#      upper_95_ci_1
# 2065             *
# 2066             *
# 2067             *
# 2068             *
# 2069             *
# 2070             *
# 2071             *
# 2072             *
# 2073             *
# 2074             *
# 2075             *
# 2076             *
# 2077             *
# 2078             *
# 2079             *
# 2080             *
# 2081             *
# 2082             *
# 2083             *
# 2084             *
# 2085             *
# 2086             *
# 2087             *
# 2088             *
# 2089             *
# 2090             *
# 2091             *
# 2092             *
# 2093             *
# 2094             *
# ...            ...
# 3112             ¶
# 3113             ¶
# 3114             ¶
# 3115             ¶
# 3116             ¶
# 3117             ¶
# 3118             ¶
# 3119             ¶
# 3120             ¶
# 3121             ¶
# 3122             ¶
# 3123             ¶
# 3124             ¶
# 3125            ¶¶
# 3126            ¶¶
# 3127            ¶¶
# 3128            ¶¶
# 3129            ¶¶
# 3130            ¶¶
# 3131            ¶¶
# 3132            ¶¶
# 3133            ¶¶
# 3134            ¶¶
# 3135            ¶¶
# 3136            ¶¶
# 3137            ¶¶
# 3138            ¶¶
# 3139            ¶¶
# 3140            ¶¶
# 3141            ¶¶
#
# [1077 rows x 10 columns]

# %%
incidence.loc[error_mask, 'Rate_per_100k'].value_counts()
# Out:
# *      868
# ¶      192
# ¶¶      17
# Name: Rate_per_100k, dtype: int64

# %%
incidence = incidence[~error_mask]

# %% [markdown]
# Okay, this is now our cleaned dataset.

# %%
incidence
# Out:
#                                    County     FIPS Rate_per_100k lower_95  \
# 0                    US (SEER+NPCR)(1,10)      0.0         16.4      16.3
# 1             Cass County, Illinois(6,10)  17017.0         41.1        28
# 2             Union County, Florida(6,10)  12125.0         38.7      26.6
# 3           Greene County, Illinois(6,10)  17061.0         37.5      24.7
# 4        Benton County, Mississippi(6,10)  28009.0         36.6      21.2
# 5         Hamilton County, Illinois(6,10)  17065.0         36.3      22.1
# 6        Holmes County, Mississippi(6,10)  28051.0         36.2      25.1
# 7              Dawson County, Texas(6,10)  48115.0         36.2      23.5
# 8              Powell County, Kentucky(7)  21197.0         35.8      22.5
# 9          Edmonson County, Kentucky(7,8)  21061.0         34.4      22.2
# 10              Nolan County, Texas(6,10)  48353.0         34.2      22.8
# 11            Henry County, Kentucky(7,8)  21103.0         34.1        23
# 12    Sunflower County, Mississippi(6,10)  28133.0         33.8      24.6
# 13            Clay County, Illinois(6,10)  17025.0         33.3      21.3
# 14        Roosevelt County, Montana(6,10)  30085.0         33.1      18.8
# 15         Johnson County, Illinois(6,10)  17087.0         31.8      20.3
# 16               Owen County, Kentucky(7)  21187.0         31.8      19.1
# 17      Webster County, Mississippi(6,10)  28155.0         31.8      18.7
# 18        Harrison County, Missouri(6,10)  29081.0         31.4      17.2
# 19           Martin County, Indiana(6,10)  18101.0         30.9      18.9
# 20       Iberville Parish, Louisiana(7,8)  22047.0         30.9      23.2
# 21           Wayne County, Missouri(6,10)  29223.0         30.9      20.3
# 22          Wilbarger County, Texas(6,10)  48487.0         30.8      19.5
# 23             Clay County, Kentucky(7,8)  21051.0         30.7      21.3
# 24             McLean County, Kentucky(7)  21149.0         30.7      18.1
# 25         Osceola County, Michigan(6,10)  26133.0       30.7        22.3
# 26      St. Helena Parish, Louisiana(7,8)  22091.0         30.5        18
# 27         Choctaw County, Oklahoma(6,10)  40023.0         30.5      19.6
# 28            Coleman County, Texas(6,10)  48083.0         30.4      18.1
# 29     Swain County, North Carolina(6,10)  37173.0         30.3      19.5
# ...                                   ...      ...           ...      ...
# 2035            Greene County, Georgia(7)  13133.0         10.7         6
# 2036        Jackson County, Florida(6,10)  12063.0         10.6       7.2
# 2037        Teller County, Colorado(6,10)   8119.0         10.5       6.1
# 2038        Marin County, California(7,8)   6041.0         10.5       9.1
# 2039        Oceana County, Michigan(6,10)  26127.0       10.5         6.1
# 2040          York County, Virginia(6,10)  51199.0         10.5       7.5
# 2041       Patrick County, Virginia(6,10)  51141.0         10.5         6
# 2042       Fairfax County, Virginia(6,10)  51059.0         10.4       9.6
# 2043  Carroll County, New Hampshire(6,10)  33003.0         10.3       7.1
# 2044         Polk County, Wisconsin(6,10)  55095.0         10.2       6.9
# 2045         Adams County, Nebraska(6,10)  31001.0         10.2       6.2
# 2046            Coffee County, Georgia(7)  13069.0         10.1       6.4
# 2047        Pettis County, Missouri(6,10)  29159.0          9.9       6.4
# 2048    Kittitas County, Washington(6,10)  53037.0          9.8         6
# 2049         Barry County, Michigan(6,10)  26015.0        9.8         6.9
# 2050     Arlington County, Virginia(6,10)  51013.0          9.8       7.8
# 2051       Gratiot County, Michigan(6,10)  26057.0        9.7         6.2
# 2052              Kauai County, Hawaii(7)  15007.0          9.7       6.9
# 2053        Warren County, Virginia(6,10)  51187.0          9.5       5.8
# 2054       Carroll County, Virginia(6,10)  51035.0          9.5       5.6
# 2055          Page County, Virginia(6,10)  51139.0          9.1       5.2
# 2056         Eagle County, Colorado(6,10)   8037.0            9         5
# 2057         Henry County, Virginia(6,10)  51089.0          8.8         6
# 2058       Suwannee County, Florida(6,10)  12121.0          8.5       5.5
# 2059       Sheridan County, Wyoming(6,10)  56033.0          8.5       4.8
# 2060                    Puerto Rico(6,10)  72001.0          8.1       7.7
# 2061         DeSoto County, Florida(6,10)  12027.0          7.9       4.6
# 2062        Collier County, Florida(6,10)  12021.0          7.7       6.6
# 2063     Marquette County, Michigan(6,10)  26103.0        7.3         4.8
# 2064      Garfield County, Colorado(6,10)   8045.0          6.6         4
#
#      upper_95 average_annual_count   trend 5_yr_trend lower_95_ci_1  \
# 0        16.4                58599  rising       0.8            0.6
# 1        58.5                    7  rising      35.1           19.0
# 2        54.9                    7  stable     -16.9          -37.4
# 3        54.9                    6  stable      28.7          -19.6
# 4        59.1                    4  stable      23.4           -1.4
# 5        57.2                    4  stable       2.5          -43.0
# 6        50.6                    7  stable      35.1          -15.2
# 7        53.4                    5  stable      -5.2          -37.9
# 8        54.3                    5       *          *             *
# 9        51.3                    5  rising       8.1            2.7
# 10       49.5                    6  stable      26.5          -25.6
# 11         49                    6  rising       6.2            0.7
# 12       45.4                    9  stable      -6.3          -42.9
# 13       49.8                    5  stable     -14.9          -55.9
# 14       53.8                    3       *          *             *
# 15         48                    5  stable      -4.2          -36.9
# 16       50.2                    4       *          *             *
# 17       50.7                    4  stable      -7.4          -30.5
# 18       52.9                    3       *          *             *
# 19       48.4                    4  stable       9.1          -31.3
# 20       40.4                   11  stable       4.5            0.0
# 21       45.6                    6  stable      19.3          -54.2
# 22       46.5                    5  stable     -16.2          -45.3
# 23       42.9                    7  rising       7.7            0.9
# 24       49.2                    4       *          *             *
# 25       41.4                   10  stable      -6.6          -24.9
# 26       48.6                    4  stable       4.9           -2.8
# 27       45.3                    6  stable      -8.1          -33.1
# 28       49.2                    4  stable       1.5          -33.9
# 29       45.2                    5  rising      31.1            2.1
# ...       ...                  ...     ...        ...           ...
# 2035     18.7                    3       *          *             *
# 2036       15                    7  stable      24.5           -9.3
# 2037     17.8                    4  stable      -9.7          -47.2
# 2038     12.2                   40  rising       1.2            0.2
# 2039     17.2                    4  rising      42.5           12.7
# 2040     14.3                    8  stable      20.3           -7.9
# 2041     17.9                    3       *          *             *
# 2042     11.3                  119  stable       2.8           -9.5
# 2043     14.7                    8  stable     -11.6          -33.2
# 2044     14.7                    6  stable       2.8          -26.8
# 2045     15.9                    4  stable      -4.5          -46.2
# 2046     15.2                    5       *          *             *
# 2047     14.8                    5  stable      10.5          -48.2
# 2048     15.2                    4  stable     -25.9          -67.1
# 2049     13.6                    8  stable      -6.5          -17.0
# 2050     12.1                   18  stable      -4.5          -24.1
# 2051     14.7                    5  stable       7.3          -43.3
# 2052     13.2                    9       *          *             *
# 2053     14.8                    4  stable      -2.0          -43.1
# 2054     15.3                    4  stable     -28.8          -56.7
# 2055     15.3                    3       *          *             *
# 2056     14.9                    4  stable      -2.2          -40.4
# 2057     12.6                    7  stable      -9.2          -35.9
# 2058     12.7                    5  stable       6.0          -26.0
# 2059       14                    3       *          *             *
# 2060      8.5                  355  stable       4.9           -0.9
# 2061     12.9                    4  stable       1.8          -24.6
# 2062      8.9                   43  stable     -10.2          -37.8
# 2063     10.6                    6  stable       8.1          -17.5
# 2064     10.2                    4  stable       0.0          -24.7
#
#      upper_95_ci_1
# 0              0.9
# 1             53.4
# 2             10.4
# 3            106.1
# 4             54.4
# 5             84.2
# 6            115.1
# 7             44.8
# 8                *
# 9             13.8
# 10           115.0
# 11            12.0
# 12            53.7
# 13            64.2
# 14               *
# 15            45.5
# 16               *
# 17            23.3
# 18               *
# 19            73.2
# 20             9.2
# 21           210.4
# 22            28.5
# 23            14.9
# 24               *
# 25            16.0
# 26            13.2
# 27            26.2
# 28            55.9
# 29            68.3
# ...            ...
# 2035             *
# 2036          70.8
# 2037          54.5
# 2038           2.2
# 2039          80.1
# 2040          57.1
# 2041             *
# 2042          16.6
# 2043          16.9
# 2044          44.3
# 2045          69.4
# 2046             *
# 2047         135.6
# 2048          66.9
# 2049           5.5
# 2050          20.2
# 2051         103.1
# 2052             *
# 2053          69.0
# 2054          17.2
# 2055             *
# 2056          60.2
# 2057          28.7
# 2058          51.8
# 2059             *
# 2060          11.0
# 2061          37.4
# 2062          29.6
# 2063          41.7
# 2064          32.8
#
# [2065 rows x 10 columns]

# %%
incidence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2065 entries, 0 to 2064
# Data columns (total 10 columns):
# County                  2065 non-null object
# FIPS                    2065 non-null float64
# Rate_per_100k           2065 non-null object
# lower_95                2065 non-null object
# upper_95                2065 non-null object
# average_annual_count    2065 non-null object
# trend                   2065 non-null object
# 5_yr_trend              2065 non-null object
# lower_95_ci_1           2065 non-null object
# upper_95_ci_1           2065 non-null object
# dtypes: float64(1), object(9)
# memory usage: 177.5+ KB

# %%
incidence['FIPS'] = incidence['FIPS'].astype(int)

for col in incidence.columns[2:]:
    if col == 'trend':
        continue
    incidence[col] = pd.to_numeric(incidence[col], errors='coerce')
    
# We have already checked the weighted average works well, can drop the very first row
incidence.drop(0, inplace=True)

# %%
incidence.to_pickle('kidney_incidence.pkl')

# %% [markdown]
# ### Some initial naive plots

# %%
incidence['population'] = (100000*incidence['average_annual_count']/incidence['Rate_per_100k']).astype(int)

# %%
largish = incidence['population'] > 50000
# Estimate the beta parameters using the method of moments
variance_in_rate = incidence.loc[largish, 'Rate_per_100k'].var()/100000

average_rate = incidence.loc[largish, 'Rate_per_100k'].mean()/100000

alpha0 = average_rate*(average_rate*(1-average_rate)/variance_in_rate - 1)
beta0 = (1-average_rate)*(average_rate*(1-average_rate)/variance_in_rate - 1)

# %%
average_rate
# Out:
# 0.00017137219730941738

# %%
average_rate*(1-average_rate)/variance_in_rate
# Out:
# 1.6954351588215515

# %%
from scipy.stats import beta
plt.figure(dpi=130)
X = np.linspace(0, 0.001, 100)
plt.plot(X, beta.pdf(X, a=23, b=130000, loc=0, scale=1)/60)
plt.hist(incidence['Rate_per_100k']/100000, bins=50);

# %%
# use a = 23, b = 130000 for our shrinkage estimates
alpha0, beta0 = 23, 130000
incidence['shrinkage'] = 100000*(incidence['average_annual_count'] + alpha0)/(incidence['population'] + beta0 + alpha0)

# %%
alpha0, beta0, _, __ = beta.fit(incidence['Rate_per_100k']/1e5, floc=0., fscale=1.)

# %%
alpha0, beta0
# Out:
# (19.366567948095202, 106389.18721541032)

# %%
plt.figure(dpi=130)
X = np.linspace(0, 0.001, 200)
plt.plot(X, beta.pdf(X, a=alpha0, b=beta0, loc=0, scale=1), label='Beta dist')
plt.hist(incidence['Rate_per_100k']/100000, bins=50, normed=True, label='data')
plt.xlim(0,5e-4)
plt.title('Best fit beta distribution')
plt.legend()
plt.xlabel('Prob of Kidney Disease')
plt.ylabel('PDF');
